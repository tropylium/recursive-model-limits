# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path

# Change to project root
os.chdir("..")

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from dotenv import load_dotenv

from src.models import *

load_dotenv()

# %%
config = ResNetConfig(num_classes=10, size="18")
model = ConfiguredResNet(config)
print("loaded model!")
